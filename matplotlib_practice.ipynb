# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import statistics
import numpy as np
import pandas as pd

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis,y_axis)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x_axis,y_axis)

# %%
ax = plt.axes()
ax.plot(x_axis,y_axis,marker = 'D',color = 'green', linewidth=3)
ax.set(title='PyBer')
# Out:
# [Text(0.5, 1.0, 'PyBer')]

# %%
plt.plot(x_axis,y_axis,marker='*',color='blue',linewidth=2,label = 'Boston')
plt.xlabel('Date')
plt.ylabel('Fare($)')
plt.ylim(0,45)
plt.title('PyBer Fare by Month')
plt.legend()

# %%
plt.barh(x_axis,y_axis,color='green',label='Boston')
plt.gca().invert_yaxis()
plt.xlabel('Date')
plt.ylabel('Fare($)')
plt.title('PyBer Fare By Month')
plt.legend()

# %%
plt.barh(x_axis,y_axis,color='green', label='Boston')
plt.xlabel('Fares($)')
plt.ylabel('Date')
plt.title('PyBer Fare by Month')
plt.legend()

# %%
fig, ax=plt.subplots()
ax.bar(x_axis,y_axis,color='black',label='New York City')
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots()
ax.barh(x_axis,y_axis,color='black',label='NYC')
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots()
ax.bar(x_axis,y_axis,color='cyan',label='Chicago')
ax.set_xlabel('Date')
ax.set_ylabel('Fare($)')
ax.set_title('PyBer Fares by Month')
ax.invert_xaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis,y_axis,'o')

# %%
plt.scatter(y_axis,x_axis,color='red',marker='x',label='Chicago')
plt.legend()
plt.title('PyBer data v ride fare')
plt.xlim(0,45)
plt.gca().invert_yaxis()

# %%
larger_y_values = []
for value in y_axis:
    larger_y_values.append(value*3)
plt.scatter(x_axis,y_axis,[i*3 for i in y_axis])
plt.gca().invert_xaxis()

# %%
fig, ax = plt.subplots()
ax.scatter(y_axis,x_axis,s=[i*5 for i in y_axis],color='cyan',alpha=0.2,edgecolor='black',label='Chicago')
ax.set_xlabel('date')
ax.set_ylabel('Fare($) per ride')
ax.set_title('title')
ax.set_xlim(xmax=45)
ax.invert_yaxis()
ax.legend()

# %%
plt.plot(x_axis,y_axis,color='green', marker = 'x')
plt.title('PyBer data vs. fare')
plt.xlabel('date')
plt.ylabel('Fare($)')
plt.gca().invert_xaxis()

# %%
stdev=statistics.stdev(y_axis)

# %%
print(stdev)
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis,y_axis,yerr=stdev,capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax = plt.subplots()
ax.errorbar(x_axis,y_axis,yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax = plt.subplots()
ax.errorbar(x_axis,y_axis,yerr=stdev,capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax = plt.subplots()
ax.barh(x_axis,y_axis,color='red')
ax.invert_yaxis()
ax.set_xticks(np.arange(0,51,step=5))
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()

# %%
file_to_load='Resources/Pyber_ride_data.csv'

# %%
PyBer_ride_data = pd.read_csv(file_to_load)

# %%
PyBer_ride_data
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09
